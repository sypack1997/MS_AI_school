# %%
# %pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4
import requests

# %%
url = 'https://search.shopping.naver.com/search/category/100005307'
result = requests.get(url).text
result
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/img/favicon.ico"/><meta property="og:title" content="네이버 쇼핑"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="네이버쇼핑 카테고리 검색 결과입니다"/><meta name="next-head-count" content="7"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/277006f34b65e940.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/277006f34b65e940.css" data-n-g=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/fbe0912620d9106d.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/fbe0912620d9106d.css" data-n-p=""/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/7fd8677a83dcad95.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/7fd8677a83dcad95.css"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/9cc29895cd309785.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/9cc29895cd309785.css"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/6b86179bdc38131c.css" as="style"/><link rel="stylesheet" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/css/6b86179bdc38131c.css"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/1117.e5847bfba1f118c2.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/8772.ab4f50d00b5ede36.js"></script><script defer="" src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/9084.c6da3990b5cabf16.js"></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/webpack-7a7c4f369db8e82b.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/framework-2ba54a73108076ed.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/main-7191483071d7e180.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/pages/_app-7d403e592b2b833b.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/7176-b6803ac2346a951c.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/1284-f2d47d1dedb602fb.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-141332/_next/static/chunks/8802-89f0b4161b6ad6a4.js" defer=""></script><script src="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221020-1413 ...

# %%
bsObj = bs4.BeautifulSoup(result, 'html.parser')

# %%
items = bsObj.find_all('a',{'class':'basicList_link__JLQJf'})

# %%
print(items[0].text)
print(items[1].text)
print(items[2].text)
print(items[3].text)
# Out:
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# LG전자 LG그램 16ZD90Q-SX76K
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A
# 삼성전자 노트북 플러스2 NT550XDA-K14A

# %%
lists = items[:4]
for l in lists:
  print(l.text)
# Out:
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# LG전자 LG그램 16ZD90Q-SX76K
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A
# 삼성전자 노트북 플러스2 NT550XDA-K14A
