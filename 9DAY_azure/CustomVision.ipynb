# %%
# !pip install azure-cognitiveservices-vision-customvision

# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch, ImageFileCreateEntry, Region
from msrest.authentication import ApiKeyCredentials
import os, time, uuid

# %%
ENDPOINT = 'https://labuser45custom.cognitiveservices.azure.com/'

training_key = '3b8c9ea01aae421ca7b7a72b79fdc6f3'
prediction_key = 'f16f120f322a4ea2a8d43a08e4bde4ed'
prediction_resource_id_key = '/subscriptions/7ae06d59-97e1-4a36-bbfe-efb081b9b03b/resourceGroups/RG45/providers/Microsoft.CognitiveServices/accounts/labuser45custom'

# %%
publish_iteration_name = "classifyModel"

credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

# %%
print("Creating project...")
project = trainer.create_project("Labuser45 Project")
# Out:
# Creating project...

# %%
Jajangmyeon_tag = trainer.create_tag(project.id, "Jajamgmyeon")
Champon_tag = trainer.create_tag(project.id, "Champon")
Tangsuyug_tag = trainer.create_tag(project.id, "Tangsuyug")
# Out:
# ---------------------------------------------------------------------------
# CustomVisionErrorException                Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 Jajangmyeon_tag = trainer.create_tag(project.id, "Jajamgmyeon")
#       2 Champon_tag = trainer.create_tag(project.id, "Champon")
#       3 Tangsuyug_tag = trainer.create_tag(project.id, "Tangsuyug")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\azure\cognitiveservices\vision\customvision\training\operations\_custom_vision_training_client_operations.py:2945, in CustomVisionTrainingClientOperationsMixin.create_tag(self, project_id, name, description, type, custom_headers, raw, **operation_config)
#    2942 response = self._client.send(request, stream=False, **operation_config)
#    2944 if response.status_code not in [200]:
# -> 2945     raise models.CustomVisionErrorException(self._deserialize, response)
# ...

# %%
import time

# %%
print('Training...')
iteration = trainer.train_project(project.id)
while (iteration.status != 'Completed'):
    iteration = trainer.get_iteration(project.id, iteration.id)
    print('Training status' + iteration.status)

    time.sleep(2)

print('Done!')
# Out:
# Training...
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# Training statusTraining
# ...
